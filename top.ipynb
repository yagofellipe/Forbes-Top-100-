# %%
# Importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")

# %%
# Importando dataset
data = pd.read_csv('forbes_2022_billionaires.csv', sep = ",")
df = pd.DataFrame(data)
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
# removendo uma coluna
df.drop('country', axis = 1, inplace = True)

# %%
# verificando a quantidade de valores nulos

df.isnull().sum()
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# dtype: int64

# %%
# Média mundial de acordo com a idade
fortuna_mundial_media = df.groupby('age')['finalWorth'].mean()
fmm = fortuna_mundial_media

# %%
# Média brasileira de acordo com idade
df_brasil = df[df['countryOfCitizenship']=='Brazil'].copy()
fortuna_brasil_media = df_brasil.groupby('age')['finalWorth'].mean()
fortuna_brasil_media
# Out:
# age
# 25.0     1500.000000
# 26.0     1500.000000
# 31.0     1100.000000
# 36.0     1100.000000
# 40.0    10600.000000
# 45.0     2000.000000
# 48.0     1600.000000
# 49.0     2950.000000
# 50.0     4300.000000
# 51.0     1600.000000
# 52.0     1433.333333
# 53.0     5800.000000
# 55.0     5100.000000
# 58.0     1300.000000
# 59.0     2600.000000
# 60.0     1600.000000
# 62.0     1700.000000
# 64.0     2050.000000
# 65.0     1650.000000
# 66.0     1600.000000
# 67.0     2300.000000
# 68.0     2200.000000
# 69.0     1200.000000
# 70.0     1400.000000
# 72.0     4060.000000
# 73.0     1000.000000
# 74.0     4066.666667
# 75.0     2300.000000
# 76.0     2100.000000
# 77.0     9800.000000
# 79.0     1500.000000
# 81.0     1100.000000
# 82.0     8350.000000
# 85.0     2700.000000
# 86.0     2000.000000
# 89.0     5500.000000
# 91.0     4100.000000
# Name: finalWorth, dtype: float64

# %%
# Média mundial e média brasileira
df['finalWorth'].mean
df_brasil['finalWorth'].mean()
# Out:
# 3011.2903225806454

# %%
# quantidade de bilionarios por setor
setworld = df['category'].value_counts()
plt.pie(x=setworld.values, labels = setworld.index, autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2130c358190>,
# ...
#  [Text(0.9848833042441147, 0.48990292612026204, 'Finance & Investments'),
#   Text(0.26547167009051936, 1.0674852656497655, 'Technology'),
#   Text(-0.581470316368077, 0.9337517181685978, 'Manufacturing'),
#   Text(-1.0432427498610704, 0.34877580888346105, 'Fashion & Retail'),
#   Text(-1.0717163537428664, -0.24783877243098096, 'Healthcare'),
#   Text(-0.8256701691094684, -0.7268210039911766, 'Food & Beverage'),
#   Text(-0.4107592729923426, -1.0204297230337827, 'Real Estate'),
#   Text(0.06213928072702369, -1.0982434656262374, 'Diversified'),
#   Text(0.41316114198044734, -1.019459597412969, 'Media & Entertainment'),
#   Text(0.6332896686831644, -0.8994132507024611, 'Energy'),
#   Text(0.7950231523729653, -0.7602224590150919, 'Automotive'),
#   Text(0.9075402433009789, -0.6215872479300071, 'Metals & Mining'),
#   Text(0.986607724729212, -0.48642080291106765, 'Service'),
# ...

# %%
# porcentagem de bilionarios por setor nos EUA

####### fazer um gráfico de pizza com porcetentagem e discursar como o setor de tech não é desenvolvido
setoreseua=df_eua['category'].value_counts()
plt.pie(x=setoreseua.values, labels = setoreseua.index, autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x213065229e0>,
# ...
#  [Text(0.7325428939286135, 0.8205978969962647, 'Finance & Investments'),
#   Text(-0.718406719214207, 0.8330016721399061, 'Technology'),
#   Text(-1.0999095667079857, -0.014104788699288546, 'Food & Beverage'),
#   Text(-0.9561345875523388, -0.5438810995853038, 'Fashion & Retail'),
#   Text(-0.6370176145621977, -0.8967767608148014, 'Real Estate'),
#   Text(-0.24935456851542123, -1.0713646900847946, 'Media & Entertainment'),
#   Text(0.10562535517288832, -1.0949170216708668, 'Energy'),
#   Text(0.4018751519118851, -1.0239611136541267, 'Healthcare'),
#   Text(0.6408449146213635, -0.8940457456998145, 'Manufacturing'),
#   Text(0.8190304889689637, -0.7342949394754538, 'Sports'),
#   Text(0.9394362471925092, -0.5722408037363771, 'Service'),
#   Text(1.0124021973663306, -0.4301648413896997, 'Automotive'),
#   Text(1.0603591565997164, -0.29264049448963586, 'Diversified'),
# ...

# %%
# porcentagem de bilionarios por setor no Brasil

####### fazer um gráfico de pizza com porcetentagem e discursar como o setor de tech não é desenvolvido
setoresbrasa=df_brasil['category'].value_counts()
plt.pie(x=setoresbrasa.values, labels = setoresbrasa.index, autopct='%1.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21308015600>,
# ...
#  [Text(0.7972720831188815, 0.7578635929237394, 'Finance & Investments'),
#   Text(-0.5338320992360116, 0.9617813108109728, 'Diversified'),
#   Text(-1.0943562456479174, 0.111285253342008, 'Food & Beverage'),
#   Text(-0.8346340171946562, -0.7165096352049359, 'Healthcare'),
#   Text(-0.11128530457252109, -1.0943562404382776, 'Fashion & Retail'),
#   Text(0.5338320091875437, -0.9617813607919372, 'Manufacturing'),
#   Text(0.8698531977687187, -0.6733167266090562, 'Media & Entertainment'),
#   Text(1.0108535167938453, -0.43379161769853913, 'Technology'),
#   Text(1.0774828952520095, -0.22142856735152225, 'Energy'),
#   Text(1.098588147539615, -0.05571428977808878, 'Real Estate')],
#  [Text(0.43487568170120805, 0.4133801415947669, '24%'),
#   Text(-0.2911811450378245, 0.5246079877150761, '18%'),
#   Text(-0.5969215885352277, 0.060701047277458904, '13%'),
#   Text(-0.4552549184698124, -0.3908234373845105, '13%'),
# ...

# %%
setoresbrasa.index
# Out:
# Index(['Finance & Investments', 'Diversified', 'Food & Beverage', 'Healthcare',
#        'Fashion & Retail', 'Manufacturing', 'Media & Entertainment',
#        'Technology', 'Energy', 'Real Estate'],
#       dtype='object')

# %%
#relação de pessoas no Brasil de Diversificados
df_bra_tech = df[(df.countryOfCitizenship=='Brazil') & (df.=='Diversified')]
df_bra_tech
# Out:
#       rank                                personName   age  finalWorth  year  \
# 357    350                      Lucia Maggi & family  89.0      6900.0  2022
# 718    709        Ermirio Pereira de Moraes & family  89.0      4100.0  2022
# 719    709  Maria Helena Moraes Scripilliti & family  91.0      4100.0  2022
# 1615  1579                      Pedro Moreira Salles  62.0      1900.0  2022
# 1698  1645           Fernando Roberto Moreira Salles  75.0      1800.0  2022
# 1699  1645                       Joao Moreira Salles  60.0      1800.0  2022
# 2217  2190            Jose Roberto Ermirio de Moraes  64.0      1300.0  2022
# 2218  2190               Jose Ermirio de Moraes Neto  69.0      1300.0  2022
# 2261  2190                    Neide Helena de Moraes  67.0      1300.0  2022
# 2392  2324            Rubens Menin Teixeira de Souza  66.0      1200.0  2022
# 2448  2448               Joao Alves de Queiroz Filho  69.0      1100.0  2022
#
# ...

# %%
#Relação de pessoas no Brasil de Tech
df_bra_tech = df[(df.countryOfCitizenship=='Brazil') & (df.category=='Technology')]
df_bra_tech
# Out:
#       rank       personName   age  finalWorth  year  month    category  \
# 186    185  Eduardo Saverin  40.0     10600.0  2022      4  Technology
# 2223  2190       Luiz Frias  58.0      1300.0  2022      4  Technology
#
#                source state       city  ...    organization selfMade  gender  \
# 186          Facebook   NaN  Singapore  ...  Meta Platforms     True       M
# 2223  mobile payments   NaN  Sao Paulo  ...             NaN    False       M
#
#        birthDate                     title philanthropyScore  residenceMsa  \
# 186   1982-03-19                  Investor               NaN           NaN
# 2223  1963-04-06  Entrepreneur, Journalist               NaN           NaN
#
#      numberOfSiblings                                                bio  \
# 186               NaN  Eduardo Saverin cofounded Facebook with Harvar...
# 2223              3.0  Luiz Frias is chairman of PagSeguro Digital, a...
#
#                                                   about
# ...

# %%
#Relação de pessoas no EUA de Tech
df_eua = df[df['countryOfCitizenship']=='United States'].copy()
df_eua_tech = df[(df.countryOfCitizenship=='United States') & (df.category=='Technology')]
df_eua_tech
# Out:
#       rank     personName   age  finalWorth  year  month    category  \
# 1        2     Jeff Bezos  58.0    171000.0  2022      4  Technology
# 3        4     Bill Gates  66.0    129000.0  2022      4  Technology
# 5        6     Larry Page  49.0    111000.0  2022      4  Technology
# 6        7    Sergey Brin  48.0    107000.0  2022      4  Technology
# 7        8  Larry Ellison  77.0    106000.0  2022      4  Technology
# ...    ...            ...   ...         ...   ...    ...         ...
# 2541  2448    Scott Smith  72.0      1100.0  2022      4  Technology
# 2588  2578  Ronald Clarke  66.0      1000.0  2022      4  Technology
# 2615  2578    Jeff Lawson  44.0      1000.0  2022      4  Technology
# 2641  2578   Neerja Sethi  67.0      1000.0  2022      4  Technology
# 2644  2578   Mike Speiser  51.0      1000.0  2022      4  Technology
#
#                           source       state           city  ...  \
# 1                         Amazon  Washington        Seattle  ...
# ...

# %%
#Diferença de bilionários em tech dos EUA e Brasil
dif_tech = len(df_eua_tech)/len(df_bra_tech)
dif_tech
# Out:
# 70.0

# %% [markdown]
# O Brasil é quase 12 vezes inferior aos EUA em relação à bilionários e é 70 vezes inferior levando em consideração a categoria tecnologia. Esse último valor considera o Eduardo Saverin, porém o Facebook foi fundado nos EUA. O único brasileiro de tecnologia criada no Brasil, segundo a forbes, é Luiz Frias.

# %%
# Superação dos EUA em relação ao Brasil em todos os setores
dif = len(df_eua)/len(df_brasil)
dif
# Out:
# 11.85483870967742

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-09-19 14:24:36.684765&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# vericando se são selfmades
(df['selfMade'] == 'True').count()
# Out:
# 2668

# %%
# vericando se são selfmades
df[(df['age'] < 20)]
# Out:
#       rank           personName   age  finalWorth  year  month  \
# 1311  1292  Kevin David Lehmann  19.0      2400.0  2022      4
#
#               category      source state city  ... organization selfMade  \
# 1311  Fashion & Retail  drugstores   NaN  NaN  ...          NaN    False
#
#       gender   birthDate title philanthropyScore  residenceMsa  \
# 1311       M  2002-09-01   NaN               NaN           NaN
#
#      numberOfSiblings                                                bio  \
# 1311              NaN  Kevin David Lehmann owns 50% of Germany's lead...
#
#                                                   about
# 1311  The dm philosophy, that ensuring employee well...
#
# [1 rows x 21 columns]

# %%
#selecionando os selfmades e americanos
df[(df['selfMade'] == 1) & (df['country'] == 'United States')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\usuario\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# ...

# %%
# filtrando os maiores filantropos
df[df['philanthropyScore'] >= 4 ]
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# 11      12         Michael Bloomberg  80.0     82000.0  2022      4
# 29      30           MacKenzie Scott  51.0     43600.0  2022      4
# 111    112               Donald Bren  89.0     16200.0  2022      4
# 201    201             George Kaiser  79.0      9900.0  2022      4
# 215    214              Gordon Moore  93.0      9500.0  2022      4
# 243    241            Bernard Marcus  92.0      8700.0  2022      4
# 248    246              George Soros  91.0      8600.0  2022      4
# 411    411      Melinda French Gates  57.0      6200.0  2022      4
# 593    586     Julian Robertson, Jr.  89.0      4800.0  2022      4
# 596    586                Jeff Skoll  57.0      4800.0  2022      4
# 671    665              Dan Friedkin  57.0      4300.0  2022      4
# ...
